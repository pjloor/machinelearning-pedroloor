# %% [markdown]
# <a href="https://colab.research.google.com/github/pjloor/machinelearning-pedroloor/blob/main/Exercises_about_Pandas_library_PedroLoor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PRIMERA PARTE**

# %%
# PANDA HAS TWO DATA STRUCTURE
# SERIES
import pandas as pd
tmp=pd.Series(data=[100,200,300,400],index=['carlos','juan','mario','rosita'])

# %%
print(tmp)
# Out:
# carlos    100
# juan      200
# mario     300
# rosita    400
# dtype: int64

# %%
tmp.shape
# Out:
# (4,)

# %%
print(tmp['mario'])
print(tmp[-2])
# Out:
# 300
# 300

# %%
tmp*2
# Out:
# carlos    200
# juan      400
# mario     600
# rosita    800
# dtype: int64

# %%
tmp[[1,2,3]]
# Out:
# juan      200
# mario     300
# rosita    400
# dtype: int64

# %%
tmp.index
# Out:
# Index(['carlos', 'juan', 'mario', 'rosita'], dtype='object')

# %%
data = {'Nombre': ['Alice', 'Bob', 'Charlie'],
        'Edad': [25, 30, 35],
        'Ciudad': ['Ciudad A', 'Ciudad B', 'Ciudad C']}

df = pd.DataFrame(data)

print(df)
# Out:
#     Nombre  Edad    Ciudad
# 0    Alice    25  Ciudad A
# 1      Bob    30  Ciudad B
# 2  Charlie    35  Ciudad C

# %%
aux={'one':pd.Series([1,2,3], index=['apple','ball','clock']),
     'two':pd.Series([10,20,30], index=['pineapple','watermelon','banana'])}

# %%
aux
# Out:
# {'one': apple    1
#  ball     2
#  clock    3
#  dtype: int64,
#  'two': pineapple     10
#  watermelon    20
#  banana        30
#  dtype: int64}

# %%
df = pd.DataFrame(aux)

# %%
df.shape
# Out:
# (6, 2)

# %%
df
# Out:
#             one   two
# apple       1.0   NaN
# ball        2.0   NaN
# banana      NaN  30.0
# clock       3.0   NaN
# pineapple   NaN  10.0
# watermelon  NaN  20.0

# %%
df.index
# Out:
# Index(['apple', 'ball', 'banana', 'clock', 'pineapple', 'watermelon'], dtype='object')

# %%
df.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %%
df['Producto'] = df['one'] * df['two']
print(df)
# Out:
#             one   two  Producto
# apple       1.0   NaN       NaN
# ball        2.0   NaN       NaN
# banana      NaN  30.0       NaN
# clock       3.0   NaN       NaN
# pineapple   NaN  10.0       NaN
# watermelon  NaN  20.0       NaN

# %%
df['Suma'] = df['one'] + df['two']
df
# Out:
#             one   two  Producto  Suma
# apple       1.0   NaN       NaN   NaN
# ball        2.0   NaN       NaN   NaN
# banana      NaN  30.0       NaN   NaN
# clock       3.0   NaN       NaN   NaN
# pineapple   NaN  10.0       NaN   NaN
# watermelon  NaN  20.0       NaN   NaN

# %%
df['Filtro'] = df['one']>2

resultado = df[df['one'] > 2]
print(resultado)
df
# Out:
#        one  two  Producto  Suma  Filtro
# clock  3.0  NaN       NaN   NaN    True
#             one   two  Producto  Suma  Filtro
# apple       1.0   NaN       NaN   NaN   False
# ball        2.0   NaN       NaN   NaN   False
# banana      NaN  30.0       NaN   NaN   False
# clock       3.0   NaN       NaN   NaN    True
# pineapple   NaN  10.0       NaN   NaN   False
# watermelon  NaN  20.0       NaN   NaN   False

# %%
del df['Producto']

# %%
print(df)
# Out:
#             one   two  Suma  Filtro
# apple       1.0   NaN   NaN   False
# ball        2.0   NaN   NaN   False
# banana      NaN  30.0   NaN   False
# clock       3.0   NaN   NaN    True
# pineapple   NaN  10.0   NaN   False
# watermelon  NaN  20.0   NaN   False

# %%
df
# Out:
#             one   two  Suma  Filtro
# apple       1.0   NaN   NaN   False
# ball        2.0   NaN   NaN   False
# banana      NaN  30.0   NaN   False
# clock       3.0   NaN   NaN    True
# pineapple   NaN  10.0   NaN   False
# watermelon  NaN  20.0   NaN   False

# %%
tags=pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/tags.csv')
ratings=pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/ratings01.csv')
movies = pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/movies.csv')

# %%
tags.shape
# Out:
# (465564, 4)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
tags[:10]
# Out:
#    userId  movieId               tag   timestamp
# 0      18     4141       Mark Waters  1240597180
# 1      65      208         dark hero  1368150078
# 2      65      353         dark hero  1368150079
# 3      65      521     noir thriller  1368149983
# 4      65      592         dark hero  1368150078
# 5      65      668         bollywood  1368149876
# 6      65      898  screwball comedy  1368150160
# 7      65     1248     noir thriller  1368149983
# 8      65     1391              mars  1368150055
# 9      65     1617          neo-noir  1368150217

# %%
print(tags['tag'][:10])
# Out:
# 0         Mark Waters
# 1           dark hero
# 2           dark hero
# 3       noir thriller
# 4           dark hero
# 5           bollywood
# 6    screwball comedy
# 7       noir thriller
# 8                mars
# 9            neo-noir
# Name: tag, dtype: object

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
movies.tail(10)
# Out:
#        movieId                                              title  \
# 27268   131241                           Ants in the Pants (2000)
# 27269   131243                Werner - Gekotzt wird später (2003)
# 27270   131248                              Brother Bear 2 (2006)
# 27271   131250                              No More School (2000)
# 27272   131252  Forklift Driver Klaus: The First Day on the Jo...
# 27273   131254                       Kein Bund für's Leben (2007)
# 27274   131256                      Feuer, Eis & Dosenbier (2002)
# 27275   131258                                 The Pirates (2014)
# 27276   131260                                Rentun Ruusu (2001)
# 27277   131262                                   Innocence (2014)
#
#                                             genres
# 27268                               Comedy|Romance
# 27269                             Animation|Comedy
# 27270  Adventure|Animation|Children|Comedy|Fantasy
# ...

# %%
ratings.head(10)
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580
# 5       1      112     3.5  1094785740
# 6       1      151     4.0  1094785734
# 7       1      223     4.0  1112485573
# 8       1      253     4.0  1112484940
# 9       1      260     4.0  1112484826

# %%
ratings.tail(10)
# Out:
#          userId  movieId  rating   timestamp
# 1999990   13567    54004     3.5  1262994633
# 1999991   13567    58154     4.0  1262994642
# 1999992   13567    58559     5.0  1262994213
# 1999993   13567    59333     3.5  1262994526
# 1999994   13567    59369     4.0  1262764264
# 1999995   13567    59725     3.5  1262994714
# 1999996   13567    63062     5.0  1262764337
# 1999997   13567    64957     5.0  1262764172
# 1999998   13567    65216     4.5  1262994367
# 1999999   13567    66203     4.0  1262994418

# %% [markdown]
# **SEGUNDA PARTE**

# %%
import pandas as pd
movies='/content/movies.csv'
ratings='/content/ratings.csv'
tags='/content/tags.csv'

# %%
movies=pd.read_csv(movies)
ratings=pd.read_csv(ratings)
tags=pd.read_csv(tags)
#HEAD se usa para visualizar los primeros datos
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224

# %%
tags.head(3)
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992

# %%
#SHAPE SE USA PARA VER LA DIMENSION DEL VECTOR Y CANTIDAD DE DATOS
movies.shape
# Out:
# (9742, 3)

# %%
ratings.shape
# Out:
# (100836, 4)

# %%
tags.shape
# Out:
# (3683, 4)

# %%
#COLUMNS SE USA PARA VER LOS CAMPOS DE LA TABLA;
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
#DEL se usa para eliminar un campo de la tabla;
del ratings['timestamp']
del tags['timestamp']

# %%
#TAIL se usa para ver los ultimos datos de la tabla
tags.tail(5)
# Out:
#       userId  movieId               tag
# 3678     606     7382         for katie
# 3679     606     7936           austere
# 3680     610     3265            gun fu
# 3681     610     3265  heroic bloodshed
# 3682     610   168248  Heroic Bloodshed

# %%
ratings.head(10)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0
# 5       1       70     3.0
# 6       1      101     5.0
# 7       1      110     4.0
# 8       1      151     5.0
# 9       1      157     5.0

# %%
#iloc se usa para sacar una muestra de un dato;
ratings.iloc[6]
# Out:
# userId       1.0
# movieId    101.0
# rating       5.0
# Name: 6, dtype: float64

# %%
#imprimir filas especificas;
print(ratings.iloc[[30,40,50]])
# Out:
#     userId  movieId  rating
# 30       1      552     4.0
# 40       1      733     4.0
# 50       1     1023     5.0

# %%
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0

# %%
ratings.describe()
# Out:
#               userId        movieId         rating
# count  100836.000000  100836.000000  100836.000000
# mean      326.127564   19435.295718       3.501557
# std       182.618491   35530.987199       1.042529
# min         1.000000       1.000000       0.500000
# 25%       177.000000    1199.000000       3.000000
# 50%       325.000000    2991.000000       3.500000
# 75%       477.000000    8122.000000       4.000000
# max       610.000000  193609.000000       5.000000

# %%
#imprime el valor minimo de un campo especifico
print(ratings['rating'].min())
# Out:
# 0.5

# %%
#imprime el valor maximo de un campo especifico
print(ratings['rating'].max())
# Out:
# 5.0

# %%
#imprime el valor promedio de un campo especifico
print(ratings['rating'].mean())
# Out:
# 3.501556983616962

# %%
#imprime el valor de la desviacion estandar de un campo especifico;
print(ratings['rating'].std())
# Out:
# 1.042529239060635

# %%
#corr se usa para ver la correlacion
ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000  0.006773 -0.049348
# movieId  0.006773  1.000000 -0.004061
# rating  -0.049348 -0.004061  1.000000

# %%
filter=ratings['rating']>5

# %%
filter.any()
# Out:
# False

# %%
filter2=ratings['rating']<3

# %%
print(filter2.any())
# Out:
# True

# %%
aux=ratings[filter2]
print(aux.shape)
print(aux.head(3))
# Out:
# (19073, 3)
#      userId  movieId  rating
# 76        1     1219     2.0
# 143       1     2253     2.0
# 148       1     2338     2.0

# %%
#isnull es para comprobar o ver los campos vacios;
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
ratings.isnull().any()
# Out:
# userId     False
# movieId    False
# rating     False
# dtype: bool

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag        False
# dtype: bool

# %%
ratings.hist(column='rating',figsize=[9,5])
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)

# %%
tags.head(2)
# Out:
#    userId  movieId              tag
# 0       2    60756            funny
# 1       2    60756  Highly quotable

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
is_animation=movies['genres'].str.contains('Animation')

# %%
newMovies=movies[is_animation]

# %%
newMovies.shape
# Out:
# (611, 3)

# %%
newMovies.head(10)
# Out:
#      movieId                                   title  \
# 0          1                        Toy Story (1995)
# 12        13                            Balto (1995)
# 44        48                       Pocahontas (1995)
# 205      239                   Goofy Movie, A (1995)
# 272      313               Swan Princess, The (1994)
# 322      364                   Lion King, The (1994)
# 483      551  Nightmare Before Christmas, The (1993)
# 488      558                  Pagemaster, The (1994)
# 506      588                          Aladdin (1992)
# 511      594  Snow White and the Seven Dwarfs (1937)
#
#                                               genres
# 0        Adventure|Animation|Children|Comedy|Fantasy
# 12                      Adventure|Animation|Children
# 44          Animation|Children|Drama|Musical|Romance
# 205                Animation|Children|Comedy|Romance
# 272                               Animation|Children
# 322  Adventure|Animation|Children|Drama|Musical|IMAX
# ...

# %%
import pandas as pd

# %%
tags['informationdatetime']=pd.to_datetime(tags['timestamp'],unit='5')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timestamp'
#
# The above exception was the direct cause of the following exception:
#
# ...
